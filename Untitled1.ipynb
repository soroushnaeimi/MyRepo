# %%
import pandas as pd
import numpy as np
xls = pd.read_excel('/home/soroush/Desktop/Managed_Wi-Fi_Cloud_Customer_Solution_Requirements_Tool.0.1.xlsm', sheetname='Organisation and Network Setup')
xls.iloc[16,3]
xls
# Out:
#     Unnamed: 0 Unnamed: 1              Wi-Fi Cloud: Organisation Information  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                           Features
# 2          NaN          S                                      Solution Type
# 3          NaN          S                                                NaN
# 4          NaN          S                                       Organisation
# 5          NaN          S      Is the Customer an existing Telstra Customer?
# 6          NaN        NaN                                      Customer CIDN
# 7          NaN        NaN            Please enter the Customer's Network FNN
# 8          NaN        NaN                                                NaN
# 9          NaN          S  Does the Customer have an existing Managed Wi-...
# 10         NaN        NaN                                                NaN
# ...
